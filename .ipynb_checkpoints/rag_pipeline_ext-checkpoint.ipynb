# %%
import os
import json
import numpy as np
import chromadb
from sentence_transformers import SentenceTransformer
from openai import OpenAI
from dotenv import load_dotenv
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\transformers\utils\generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(

# %%
load_dotenv()

# Backend config (.env)
MODEL_BACKEND = os.getenv("MODEL_BACKEND", "ollama")
MODEL_NAME = os.getenv("MODEL_NAME", "llama3.2")
OLLAMA_API_BASE = os.getenv("OLLAMA_API_BASE", "http://localhost:11434")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "ollama")

# Configure OpenAI to talk to Ollama
os.environ["OPENAI_API_BASE"] = f"{OLLAMA_API_BASE}/v1"
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

client_ai = OpenAI()

print(f"🔗 LLM Backend: {MODEL_BACKEND} | Model: {MODEL_NAME}")
# Out:
# 🔗 LLM Backend: ollama | Model: llama3.2

# %%
CHROMA_PATH = "./chroma_aug_store"
client = chromadb.PersistentClient(path=CHROMA_PATH)
collection = client.get_collection("DBMS-25")

embedder = SentenceTransformer("all-MiniLM-L6-v2")

print("📦 Loaded ChromaDB & Embedding Model")
# Out:
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 📦 Loaded ChromaDB & Embedding Model

# %%
def to_percent(x):
    return round(float(x) * 100, 2)


def compute_cosine(a, b):
    return float(cosine_similarity([a], [b])[0][0])


def bag_of_words_similarity(text1, text2):
    vectorizer = CountVectorizer().fit([text1, text2])
    bow1 = vectorizer.transform([text1]).toarray()[0]
    bow2 = vectorizer.transform([text2]).toarray()[0]
    if np.linalg.norm(bow1) == 0 or np.linalg.norm(bow2) == 0:
        return 0.0
    return float(np.dot(bow1, bow2) / (np.linalg.norm(bow1) * np.linalg.norm(bow2)))


def call_llama_similarity(query_text, db_text):
    """
    Ask Llama3.2 to give contextual similarity score (0–100)
    """
    prompt = f"""
Rate the similarity between the following two project descriptions.
Return ONLY a number between 0 and 100.

USER PROJECT:
{query_text}

EXISTING PROJECT:
{db_text}
"""

    try:
        resp = client_ai.chat.completions.create(
            model=MODEL_NAME,
            messages=[
                {"role": "system", "content": "You are a similarity evaluator. Return only a number."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.0
        )
        score = resp.choices[0].message.content.strip()
        return float(score)
    except:
        return 0.0

# %%
title = "Smart Irrigation System using IoT"
description = "A system that monitors soil moisture and weather conditions to automate irrigation using IoT sensors and controllers."
tech_stack = "NodeMCU, DHT11, Soil Sensor, MQTT, Python, ThingSpeak"
domain = "IoT / Agriculture"
objective = "Optimize water usage by automating irrigation based on real-time environmental data."

# %%
emb_title = embedder.encode(title).tolist()
emb_desc = embedder.encode(description).tolist()
emb_tech = embedder.encode(tech_stack).tolist()
emb_domain = embedder.encode(domain).tolist()
emb_obj = embedder.encode(objective).tolist()

combined_text = f"{title} {description} {tech_stack} {domain} {objective}"
emb_whole = embedder.encode(combined_text).tolist()

print("✨ Embeddings created.")
# Out:
# ✨ Embeddings created.

# %%
TOP_K = 8

res = collection.query(
    query_embeddings=[emb_whole],
    n_results=TOP_K,
    include=["metadatas", "documents", "distances", "embeddings"]
)

ids = res["ids"][0]
docs = res["documents"][0]
metas = res["metadatas"][0]
stored_embs = res["embeddings"][0]

print("🔍 Retrieved matches from ChromaDB")
# Out:
# Add of existing embedding ID: auto001
# Add of existing embedding ID: auto002
# Add of existing embedding ID: auto003
# Add of existing embedding ID: auto004
# Add of existing embedding ID: auto005
# Add of existing embedding ID: auto006
# Add of existing embedding ID: auto007
# Add of existing embedding ID: auto008
# Add of existing embedding ID: auto009
# Add of existing embedding ID: auto010
# Add of existing embedding ID: auto011
# Add of existing embedding ID: auto012
# Add of existing embedding ID: auto013
# Add of existing embedding ID: auto014
# Add of existing embedding ID: auto015
# Add of existing embedding ID: auto001
# Add of existing embedding ID: auto002
# Add of existing embedding ID: auto003
# Add of existing embedding ID: auto004
# Add of existing embedding ID: auto005
# Add of existing embedding ID: auto006
# Add of existing embedding ID: auto007
# Add of existing embedding ID: auto008
# Add of existing embedding ID: auto009
# Add of existing embedding ID: auto010
# Add of existing embedding ID: auto001
# Add of existing embedding ID: auto002
# Add of existing embedding ID: auto003
# Add of existing embedding ID: auto004
# Add of existing embedding ID: auto005
# Add of existing embedding ID: auto006
# Add of existing embedding ID: auto007
# Add of existing embedding ID: auto008
# Add of existing embedding ID: auto009
# Add of existing embedding ID: auto010
# Add of existing embedding ID: auto011
# Add of existing embedding ID: auto012
# Add of existing embedding ID: auto013
# Add of existing embedding ID: auto014
# Add of existing embedding ID: auto015
# Add of existing embedding ID: auto016
# Add of existing embedding ID: auto017
# Add of existing embedding ID: auto018
# Add of existing embedding ID: auto019
# Add of existing embedding ID: auto020
# Add of existing embedding ID: auto021
# Add of existing embedding ID: auto022
# Add of existing embedding ID: auto023
# Add of existing embedding ID: auto024
# Add of existing embedding ID: auto025
# 🔍 Retrieved matches from ChromaDB

# %%
results = []

for i, rid in enumerate(ids):
    meta = metas[i]
    db_title = meta.get("title", "")
    db_domain = meta.get("domain", "")
    db_tech = meta.get("tech_stack", "")
    db_source = meta.get("source", "")
    db_desc = docs[i]

    # Embeddings
    db_emb = np.array(stored_embs[i])
    db_title_emb = embedder.encode(db_title).tolist()
    db_desc_emb = embedder.encode(db_desc).tolist()
    db_tech_emb = embedder.encode(db_tech).tolist()
    db_domain_emb = embedder.encode(db_domain).tolist()

    # Similarities
    sim_title = compute_cosine(emb_title, db_title_emb)
    sim_desc = compute_cosine(emb_desc, db_desc_emb)
    sim_tech = compute_cosine(emb_tech, db_tech_emb)
    sim_domain = compute_cosine(emb_domain, db_domain_emb)
    sim_objective = compute_cosine(emb_obj, embedder.encode(meta.get("objective","")).tolist())
    sim_whole = compute_cosine(emb_whole, db_emb)

    # BoW similarity
    bow_sim = bag_of_words_similarity(combined_text, db_desc)

    # LLM contextual similarity
    ctx_sim = call_llama_similarity(combined_text, db_desc)

    # Weighted final score
    final_score = (
        0.40 * sim_whole +
        0.20 * ((sim_title + sim_desc + sim_tech + sim_domain + sim_objective) / 5) +
        0.15 * bow_sim +
        0.25 * (ctx_sim / 100)
    )

    results.append({
        "project_id": rid,
        "title": db_title,
        "domain": db_domain,
        "tech_stack": db_tech,
        "whole_similarity": to_percent(sim_whole),
        "title_similarity": to_percent(sim_title),
        "description_similarity": to_percent(sim_desc),
        "tech_similarity": to_percent(sim_tech),
        "domain_similarity": to_percent(sim_domain),
        "objective_similarity": to_percent(sim_objective),
        "bow_similarity": to_percent(bow_sim),
        "contextual_similarity": ctx_sim,
        "final_similarity": to_percent(final_score),
        "snippet": db_desc[:250]
    })

# %%
results_sorted = sorted(results, key=lambda x: x["final_similarity"], reverse=True)

print("\n=== 🎯 FINAL TOP-5 MATCHES ===\n")
for r in results_sorted[:5]:
    print(f"📌 {r['title']}  |  Final Score: {r['final_similarity']}%")
    print(f"   Whole: {r['whole_similarity']}% | Title: {r['title_similarity']}% | Desc: {r['description_similarity']}%")
    print(f"   Domain: {r['domain_similarity']}% | Tech: {r['tech_similarity']}% | Obj: {r['objective_similarity']}%")
    print(f"   BoW: {r['bow_similarity']}% | Contextual: {r['contextual_similarity']}%")
    print(f"   Snippet: {r['snippet']}\n")
# Out:
# === 🎯 FINAL TOP-5 MATCHES ===
#
# 📌 Smart Farming and Agriculture  |  Final Score: 48.17%
#    Whole: 57.14% | Title: 53.2% | Desc: 63.11%
#    Domain: 70.28% | Tech: 38.89% | Obj: 50.61%
#    BoW: 25.1% | Contextual: 42.0%
#    Snippet: Another excellent idea to work for enhancing the agricultural sector. You can work on developing gadgets or technology that will help farmers have insights about the soil and climate and plan their farming methods accordingly. IoT devices like detect
#
# 📌 Weather Forecasting Application  |  Final Score: 36.46%
#    Whole: 39.7% | Title: 27.1% | Desc: 42.75%
#    Domain: 28.81% | Tech: 44.29% | Obj: 37.02%
#    BoW: 19.19% | Contextual: 42.0%
#    Snippet: For those proficient at data aggregation from multiple APIs, features of geospatial integration, data structures, ML technologies, and algorithms may work in designing weather forecasting apps. You should be able to analyze available data of a sample
#
# 📌 Rainfall Prediction system  |  Final Score: 36.3%
#    Whole: 40.05% | Title: 41.61% | Desc: 43.06%
#    Domain: 28.81% | Tech: 27.53% | Obj: 4.42%
#    BoW: 24.74% | Contextual: 43.0%
#    Snippet: This project aims to develop a model capable of predicting rainfall patterns in the future based on past meteorological data. Learners will get hands-on practice collecting and preprocessing meteorological data, using different machine learning algor
#
# 📌 The applications of ML in disease and pest detection in agriculture  |  Final Score: 34.37%
#    Whole: 37.88% | Title: 31.48% | Desc: 39.33%
#    Domain: 28.81% | Tech: 40.63% | Obj: 29.81%
#    BoW: 12.76% | Contextual: 42.0%
#    Snippet: ML has the potential to revolutionize farming in many ways. ML can help in the detection of pests and diseases in crops at an early stage by analysing pictures of leaves, stems, yield, and other crop details. Pictures can be taken by phones, drones,
#
# 📌 Fingerprint Reader:  |  Final Score: 27.17%
#    Whole: 24.79% | Title: 9.12% | Desc: 16.58%
#    Domain: 28.81% | Tech: 39.35% | Obj: 8.07%
#    BoW: 16.16% | Contextual: 43.0%
#    Snippet: Biometric systems have been gaining tremendous attention in these years with the combination of hardware and software challenges of fingerprint reader projects. Students can access affordable fingerprint sensor modules like R307, use a combination of

# %%
prompt_lines = []
prompt_lines.append("You are an expert academic evaluator specializing in project similarity analysis and originality improvement.")
prompt_lines.append("Your job is to compare the student's synopsis with top-5 similar projects and produce a clear, structured, point-wise analytical report.\n")

prompt_lines.append("=== STUDENT PROJECT SYNOPSIS ===")
prompt_lines.append(f"• Title: {title}")
prompt_lines.append(f"• Description: {description}")
prompt_lines.append(f"• Tech Stack: {tech_stack}")
prompt_lines.append(f"• Domain: {domain}")
prompt_lines.append(f"• Objective: {objective}\n")

prompt_lines.append("=== TOP-5 MOST SIMILAR PROJECTS FROM DATABASE ===")

for i, r in enumerate(results_sorted[:5], start=1):
    prompt_lines.append(f"\n{i}. {r['title']}")
    prompt_lines.append("   Similarity Breakdown:")
    prompt_lines.append(f"   • Whole Similarity: {r['whole_similarity']}%")
    prompt_lines.append(f"   • Title Similarity: {r['title_similarity']}%")
    prompt_lines.append(f"   • Description Similarity: {r['description_similarity']}%")
    prompt_lines.append(f"   • Tech Stack Overlap: {r['tech_similarity']}%")
    prompt_lines.append(f"   • Objective Similarity: {r['objective_similarity']}%")
    prompt_lines.append(f"   • Domain Match: {r['domain_similarity']}%")
    prompt_lines.append(f"   • Contextual Match Score: {r['contextual_similarity']}")
    prompt_lines.append(f"   • Relevant Snippet: {r['snippet']}\n")

prompt_lines.append(
"""
=== TASK ===

For **each** of the 5 similar projects, generate a detailed section with the following structure:

1️⃣ **Why It Was Flagged as Similar (2–3 crisp bullet points)**  
   - Identify specific overlapping concepts (keywords, functional goals, methods, problem domain).  
   - Mention pattern-level or theme-level similarity (e.g., “predictive analytics”, “database CRUD operations”, etc).  

2️⃣ **Exact Matching Components (point-wise)**  
   - Title keyword overlaps  
   - Matching description phrases  
   - Shared technical stack components  
   - Similar objectives or problem statements  
   - Domain-level commonality  
   - Any contextual similarity patterns  

3️⃣ **Uniqueness Enhancement Suggestions (2 actionable changes)**  
   - Rewrite suggestions for making the student’s project more original  
   - Clear instructions to alter scope, architecture, features, or focus  
   - Recommend new angles, datasets, modules, or problem framing  

After covering all 5 projects, generate:

4️⃣ **GENERAL ORIGINALITY GUIDELINES (5 strong, practical points)**  
   - How to avoid common similarity traps  
   - How to differentiate a project in title, description, and objective  
   - Best practices for making academically original work  
   - Technical + conceptual strategies to reduce similarity  

Format the entire output cleanly:
• Use headings  
• Use bullet points  
• Avoid long paragraphs  
• Keep analysis deep but easy to scan  
"""
)

llama_prompt = "\n".join(prompt_lines)

# ----- Call model -----
try:
    completion = client_ai.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": "You evaluate project similarities and rewrite suggestions."},
            {"role": "user", "content": llama_prompt}
        ],
        temperature=0.4
    )
    llama_analysis = completion.choices[0].message.content.strip()
except Exception as e:
    llama_analysis = f"LLAMA ERROR: {e}"

# ----- Print result -----
print("=== 🧠 LLM Similarity Breakdown & Suggestions ===\n")
print(llama_analysis)
# Out:
# === 🧠 LLM Similarity Breakdown & Suggestions ===
#
# **Project Similarity Analysis Report**
#
# ### Student Project Synopsis
#
# * Title: Smart Irrigation System using IoT
# * Description: A system that monitors soil moisture and weather conditions to automate irrigation using IoT sensors and controllers.
# * Tech Stack: NodeMCU, DHT11, Soil Sensor, MQTT, Python, ThingSpeak
# * Domain: IoT / Agriculture
# * Objective: Optimize water usage by automating irrigation based on real-time environmental data.
#
# ### Top-5 Most Similar Projects
#
# #### Project 1: Smart Farming and Agriculture
#
# **Why It Was Flagged as Similar (2–3 crisp bullet points)**
#
# * The project shares a similar focus on optimizing agricultural practices using IoT technology.
# * Both projects involve the use of sensors to monitor soil moisture, temperature, and other environmental factors.
# * The objective of both projects is to improve crop yields and reduce water waste.
#
# **Exact Matching Components (point-wise)**
#
# * Title keyword overlaps: "Smart" and "Farming"
# * Matching description phrases: "automate irrigation", "real-time environmental data"
# * Shared technical stack components: NodeMCU, DHT11
# * Similar objectives or problem statements: Optimize crop yields, reduce water waste
# * Domain-level commonality: Agriculture
# * Contextual similarity patterns: Both projects involve the use of IoT sensors to monitor and control agricultural processes.
#
# **Uniqueness Enhancement Suggestions (2 actionable changes)**
#
# * Rewrite suggestion: Instead of focusing solely on irrigation, explore how the project can integrate with other smart farming technologies, such as precision agriculture or crop monitoring.
# * Clear instructions: Consider adding a new component that incorporates machine learning algorithms to analyze soil data and predict optimal irrigation schedules.
#
# #### Project 2: Weather Forecasting Application
#
# **Why It Was Flagged as Similar (2–3 crisp bullet points)**
#
# * The project shares a similar focus on using environmental data to inform decision-making.
# * Both projects involve the use of APIs to collect and process data.
# * The objective of both projects is to provide accurate and timely information for agricultural planning.
#
# **Exact Matching Components (point-wise)**
#
# * Title keyword overlaps: None
# * Matching description phrases: "real-time environmental data", "predictive analytics"
# * Shared technical stack components: API integration
# * Similar objectives or problem statements: Provide accurate and timely information for decision-making
# * Domain-level commonality: Environmental monitoring
# * Contextual similarity patterns: Both projects involve the use of data to inform agricultural planning.
#
# **Uniqueness Enhancement Suggestions (2 actionable changes)**
#
# * Rewrite suggestion: Instead of focusing on weather forecasting, explore how the project can incorporate other environmental factors, such as soil moisture or temperature, into the decision-making process.
# * Clear instructions: Consider adding a new component that incorporates natural language processing to analyze and interpret weather forecasts.
#
# #### Project 3: Rainfall Prediction system
#
# **Why It Was Flagged as Similar (2–3 crisp bullet points)**
#
# * The project shares a similar focus on using environmental data to inform decision-making.
# * Both projects involve the use of machine learning algorithms to analyze data.
# * The objective of both projects is to provide accurate and timely information for agricultural planning.
#
# **Exact Matching Components (point-wise)**
#
# * Title keyword overlaps: "Rainfall"
# * Matching description phrases: "predictive analytics", "machine learning algorithms"
# * Shared technical stack components: Machine learning
# * Similar objectives or problem statements: Provide accurate and timely information for decision-making
# * Domain-level commonality: Environmental monitoring
# * Contextual similarity patterns: Both projects involve the use of data to inform agricultural planning.
#
# **Uniqueness Enhancement Suggestions (2 actionable changes)**
#
# * Rewrite suggestion: Instead of focusing solely on rainfall prediction, explore how the project can incorporate other environmental factors, such as soil moisture or temperature, into the decision-making process.
# * Clear instructions: Consider adding a new component that incorporates real-time data from IoT sensors to improve the accuracy of rainfall predictions.
#
# #### Project 4: The applications of ML in disease and pest detection in agriculture
#
# **Why It Was Flagged as Similar (2–3 crisp bullet points)**
#
# * The project shares a similar focus on using machine learning algorithms to analyze environmental data.
# * Both projects involve the use of computer vision techniques to analyze images or sensor data.
# * The objective of both projects is to improve crop yields and reduce waste.
#
# **Exact Matching Components (point-wise)**
#
# * Title keyword overlaps: "Machine Learning"
# * Matching description phrases: "analyze images", "sensor data"
# * Shared technical stack components: Machine learning, computer vision
# * Similar objectives or problem statements: Improve crop yields, reduce waste
# * Domain-level commonality: Agriculture
# * Contextual similarity patterns: Both projects involve the use of machine learning algorithms to analyze environmental data.
#
# **Uniqueness Enhancement Suggestions (2 actionable changes)**
#
# * Rewrite suggestion: Instead of focusing solely on disease and pest detection, explore how the project can incorporate other machine learning techniques, such as natural language processing or recommender systems, to improve crop yields.
# * Clear instructions: Consider adding a new component that incorporates real-time data from IoT sensors to improve the accuracy of disease and pest detection.
#
# #### Project 5: Fingerprint Reader
#
# **Why It Was Flagged as Similar (2–3 crisp bullet points)**
#
# * None
#
# ### General Originality Guidelines (5 strong, practical points)
#
# • **Avoid common similarity traps**: Be cautious when using similar keywords or phrases in your project title, description, and objective. Instead, focus on unique aspects of your project that set it apart from others.
#
# • **Differentiate a project in title, description, and objective**: Use clear and concise language to describe the purpose and scope of your project. Avoid using generic terms or phrases that could apply to multiple projects.
#
# • **Best practices for making academically original work**: Conduct thorough research on existing projects and identify areas where you can improve upon or expand upon previous work. Be transparent about your methods and data sources, and avoid plagiarism.
#
# • **Technical + conceptual strategies to reduce similarity**: Consider using novel techniques or approaches that are not commonly used in similar projects. For example, you could explore the use of transfer learning or attention mechanisms to improve the accuracy of your machine learning models.
#
# • **Focus on unique problem domains**: Instead of focusing solely on a specific domain or industry, consider exploring multiple domains or industries simultaneously. This can help you identify common challenges and opportunities across different fields, and develop more generalizable solutions.

# %%
import os
import json
from datetime import datetime

# -------------------------------------------
# 📁 Ensure analysis_report folder exists
# -------------------------------------------
REPORT_DIR = "analysis_report"
os.makedirs(REPORT_DIR, exist_ok=True)

REPORT_FILE = os.path.join(REPORT_DIR, "analysis_reports.json")

# -------------------------------------------
# 📌 Build final analysis report (correct keys)
# -------------------------------------------
analysis_report = {
    "query": title,
    "timestamp": str(datetime.now()),
    "results": [
        {
            "id": r.get("proj_id"),
            "title": r.get("title"),
            "domain": r.get("domain"),
            "tech_stack": r.get("tech_stack"),
            "source": r.get("source"),
            "sim_whole": r.get("overall_similarity"),
            "sim_title": r.get("title_similarity"),
            "sim_description": r.get("desc_similarity"),
            "sim_tech_stack": r.get("tech_similarity"),
            "sim_objective": r.get("objective_similarity", 0),
            "doc_snippet": r.get("snippet")
        }
        for r in results_sorted
    ],
    "ai_analysis": llama_analysis

}

# -------------------------------------------
# 📁 Create file if not exists
# -------------------------------------------
if not os.path.exists(REPORT_FILE):
    with open(REPORT_FILE, "w") as f:
        json.dump([], f, indent=4)

# -------------------------------------------
# 📌 Load → Append → Save
# -------------------------------------------
with open(REPORT_FILE, "r") as f:
    existing_reports = json.load(f)

existing_reports.append(analysis_report)

with open(REPORT_FILE, "w") as f:
    json.dump(existing_reports, f, indent=4)

print("✅ Saved to analysis_report/analysis_reports.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 35
#      11 REPORT_FILE = os.path.join(REPORT_DIR, "analysis_reports.json")
#      13 # -------------------------------------------
#      14 # 📌 Build final analysis report (correct keys)
#      15 # -------------------------------------------
#      16 analysis_report = {
#      17     "query": title,
#      18     "timestamp": str(datetime.now()),
#      19     "results": [
#      20         {
#      21             "id": r.get("proj_id"),
#      22             "title": r.get("title"),
#      23             "domain": r.get("domain"),
#      24             "tech_stack": r.get("tech_stack"),
#      25             "source": r.get("source"),
#      26             "sim_whole": r.get("overall_similarity"),
#      27             "sim_title": r.get("title_similarity"),
#      28             "sim_description": r.get("desc_similarity"),
#      29             "sim_tech_stack": r.get("tech_similarity"),
#      30             "sim_objective": r.get("objective_similarity", 0),
#      31             "doc_snippet": r.get("snippet")
#      32         }
#      33         for r in results_sorted
#      34     ],
# ---> 35     "ai_analysis": analysis_text
#      36 }
#      38 # -------------------------------------------
#      39 # 📁 Create file if not exists
#      40 # -------------------------------------------
#      41 if not os.path.exists(REPORT_FILE):
#
# NameError: name 'analysis_text' is not defined
