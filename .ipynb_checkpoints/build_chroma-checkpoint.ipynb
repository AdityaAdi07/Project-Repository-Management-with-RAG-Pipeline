# %%
import json
import chromadb
import numpy as np
import shutil
import os

# %%
CHROMA_PATH = "./chroma_store"
COLLECTION_NAME = "DBMS-25"
JSON_PATH = "embeddings/projects-embedded.json"   # <-- your final clean JSON

# %%
if os.path.exists(CHROMA_PATH):
    shutil.rmtree(CHROMA_PATH)

# New clean client
client = chromadb.PersistentClient(path=CHROMA_PATH)

# %%
collection = client.create_collection(
    name=COLLECTION_NAME,
    metadata={"hnsw:space": "cosine"}
)

print("🚀 Rebuilding Chroma collection…")
# Out:
# 🚀 Rebuilding Chroma collection…

# %%
with open(JSON_PATH, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
for item in data:

    emb = np.array(item["embedding"], dtype=float)
    dim = emb.shape[0]
    if dim != 1024:
        raise ValueError(f"Embedding dimension mismatch: expected 1024, found {dim}")

    # FIX: ensure metadata values are only str/int/float/bool
    metadata = {
        "project_id": str(item["project_id"]),
        "title": str(item["title"]),
        "description": str(item["description"]),
        "domain": str(item["domain"]),
        "year": str(item["year"]),
        "tech_stack": str(item["tech_stack"]),
        "objective": str(item["objective"]),
        "source": str(item.get("source", "")),
    }

    collection.add(
        ids=[item["project_id"]],
        embeddings=[emb.tolist()],
        metadatas=[metadata],
        documents=[item["description"]],
    )

print("✅ DONE — Chroma rebuilt cleanly with 1024-dim embeddings!")
print(f"📁 Store Path: {CHROMA_PATH}")
print(f"📊 Total items: {collection.count()}")
# Out:
# Insert of existing embedding ID: auto001
# Add of existing embedding ID: auto001
# Insert of existing embedding ID: auto002
# Add of existing embedding ID: auto002
# Insert of existing embedding ID: auto003
# Add of existing embedding ID: auto003
# Insert of existing embedding ID: auto004
# Add of existing embedding ID: auto004
# Insert of existing embedding ID: auto005
# Add of existing embedding ID: auto005
# Insert of existing embedding ID: auto006
# Add of existing embedding ID: auto006
# Insert of existing embedding ID: auto007
# Add of existing embedding ID: auto007
# Insert of existing embedding ID: auto008
# Add of existing embedding ID: auto008
# Insert of existing embedding ID: auto009
# Add of existing embedding ID: auto009
# Insert of existing embedding ID: auto010
# Add of existing embedding ID: auto010
# Insert of existing embedding ID: auto011
# Add of existing embedding ID: auto011
# Insert of existing embedding ID: auto012
# Add of existing embedding ID: auto012
# Insert of existing embedding ID: auto013
# Add of existing embedding ID: auto013
# Insert of existing embedding ID: auto014
# Add of existing embedding ID: auto014
# Insert of existing embedding ID: auto015
# Add of existing embedding ID: auto015
# Insert of existing embedding ID: auto001
# Add of existing embedding ID: auto001
# Insert of existing embedding ID: auto002
# Add of existing embedding ID: auto002
# Insert of existing embedding ID: auto003
# Add of existing embedding ID: auto003
# Insert of existing embedding ID: auto004
# Add of existing embedding ID: auto004
# Insert of existing embedding ID: auto005
# Add of existing embedding ID: auto005
# Insert of existing embedding ID: auto006
# Add of existing embedding ID: auto006
# Insert of existing embedding ID: auto007
# Add of existing embedding ID: auto007
# Insert of existing embedding ID: auto008
# Add of existing embedding ID: auto008
# Insert of existing embedding ID: auto009
# Add of existing embedding ID: auto009
# Insert of existing embedding ID: auto010
# Add of existing embedding ID: auto010
# Insert of existing embedding ID: auto001
# Add of existing embedding ID: auto001
# Insert of existing embedding ID: auto002
# Add of existing embedding ID: auto002
# Insert of existing embedding ID: auto003
# Add of existing embedding ID: auto003
# Insert of existing embedding ID: auto004
# Add of existing embedding ID: auto004
# Insert of existing embedding ID: auto005
# Add of existing embedding ID: auto005
# Insert of existing embedding ID: auto006
# Add of existing embedding ID: auto006
# Insert of existing embedding ID: auto007
# Add of existing embedding ID: auto007
# Insert of existing embedding ID: auto008
# Add of existing embedding ID: auto008
# Insert of existing embedding ID: auto009
# Add of existing embedding ID: auto009
# Insert of existing embedding ID: auto010
# Add of existing embedding ID: auto010
# Insert of existing embedding ID: auto011
# Add of existing embedding ID: auto011
# Insert of existing embedding ID: auto012
# Add of existing embedding ID: auto012
# Insert of existing embedding ID: auto013
# Add of existing embedding ID: auto013
# Insert of existing embedding ID: auto014
# Add of existing embedding ID: auto014
# Insert of existing embedding ID: auto015
# Add of existing embedding ID: auto015
# Insert of existing embedding ID: auto016
# Add of existing embedding ID: auto016
# Insert of existing embedding ID: auto017
# Add of existing embedding ID: auto017
# Insert of existing embedding ID: auto018
# Add of existing embedding ID: auto018
# Insert of existing embedding ID: auto019
# Add of existing embedding ID: auto019
# Insert of existing embedding ID: auto020
# Add of existing embedding ID: auto020
# Insert of existing embedding ID: auto021
# Add of existing embedding ID: auto021
# Insert of existing embedding ID: auto022
# Add of existing embedding ID: auto022
# Insert of existing embedding ID: auto023
# Add of existing embedding ID: auto023
# Insert of existing embedding ID: auto024
# Add of existing embedding ID: auto024
# Insert of existing embedding ID: auto025
# Add of existing embedding ID: auto025
# ✅ DONE — Chroma rebuilt cleanly with 1024-dim embeddings!
# 📁 Store Path: ./chroma_store
# 📊 Total items: 51

# %%
import chromadb
import json
import numpy as np
import shutil
import os
from sentence_transformers import SentenceTransformer

# ===============================
# CONFIG
# ===============================
OLD_CHROMA_PATH = "./chroma_store"
NEW_CHROMA_PATH = "./chroma_store_768"
COLLECTION_NAME = "DBMS-25"

JSON_FILE = "embeddings/projects-embedded.json"

# Use 768-dim embedder
EMBED_MODEL = "sentence-transformers/all-MiniLM-L6-v2"
embedder = SentenceTransformer(EMBED_MODEL)


# ===============================
# 1. Load raw JSON
# ===============================
print("📥 Loading raw project data...")
data = json.load(open(JSON_FILE, "r"))
print(f"Loaded {len(data)} projects")


# ===============================
# 2. Remove old 1024-dim store
# ===============================
if os.path.exists(NEW_CHROMA_PATH):
    shutil.rmtree(NEW_CHROMA_PATH)

client = chromadb.PersistentClient(path=NEW_CHROMA_PATH)

collection = client.create_collection(
    name=COLLECTION_NAME,
    metadata={"hnsw:space": "cosine"},
)

# ===============================
# Helper: Fix metadata values
# ===============================
def fix_meta(val):
    """Convert ANY metadata value into a valid Chroma type (string)."""
    if val is None:
        return ""

    # If already valid: return as-is
    if isinstance(val, (str, int, float, bool)):
        return val

    # If it's a list -> join elements
    if isinstance(val, list):
        return " ".join(str(x) for x in val)

    # If it's a dict -> flatten into readable string
    if isinstance(val, dict):
        flat = []
        for k, v in val.items():
            if isinstance(v, list):
                v = " ".join(str(x) for x in v)
            flat.append(f"{k}: {v}")
        return "; ".join(flat)

    # For any other weird type -> convert to string
    return str(val)



# ===============================
# 3. Rebuild Chroma
# ===============================
print("🔄 Rebuilding Chroma with 768-dim embeddings...")

for item in data:

    # Compute 768 embedding
    new_emb = embedder.encode(item["description"])
    new_emb = np.array(new_emb, dtype=np.float32).tolist()

    # FIX metadata (no lists allowed)
    meta = {
        "title": fix_meta(item.get("title")),
        "description": fix_meta(item.get("description")),
        "domain": fix_meta(item.get("domain")),
        "year": fix_meta(item.get("year")),
        "objective": fix_meta(item.get("objective")),
        "tech_stack": fix_meta(item.get("tech_stack")),
        "source": fix_meta(item.get("source")),
    }


    collection.add(
        ids=[item["project_id"]],
        embeddings=[new_emb],
        metadatas=[meta],
        documents=[item["description"]],
    )

print("✅ DONE — Chroma rebuilt with SAFE 768-dim embeddings")
print("📁 New store:", NEW_CHROMA_PATH)
print("📊 Total items:", collection.count())
# Out:
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\transformers\utils\generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 📥 Loading raw project data...
# Loaded 101 projects
# 🔄 Rebuilding Chroma with 768-dim embeddings...
# Insert of existing embedding ID: auto001
# Add of existing embedding ID: auto001
# Insert of existing embedding ID: auto002
# Add of existing embedding ID: auto002
# Insert of existing embedding ID: auto003
# Add of existing embedding ID: auto003
# Insert of existing embedding ID: auto004
# Add of existing embedding ID: auto004
# Insert of existing embedding ID: auto005
# Add of existing embedding ID: auto005
# Insert of existing embedding ID: auto006
# Add of existing embedding ID: auto006
# Insert of existing embedding ID: auto007
# Add of existing embedding ID: auto007
# Insert of existing embedding ID: auto008
# Add of existing embedding ID: auto008
# Insert of existing embedding ID: auto009
# Add of existing embedding ID: auto009
# Insert of existing embedding ID: auto010
# Add of existing embedding ID: auto010
# Insert of existing embedding ID: auto011
# Add of existing embedding ID: auto011
# Insert of existing embedding ID: auto012
# Add of existing embedding ID: auto012
# Insert of existing embedding ID: auto013
# Add of existing embedding ID: auto013
# Insert of existing embedding ID: auto014
# Add of existing embedding ID: auto014
# Insert of existing embedding ID: auto015
# Add of existing embedding ID: auto015
# Insert of existing embedding ID: auto001
# Add of existing embedding ID: auto001
# Insert of existing embedding ID: auto002
# Add of existing embedding ID: auto002
# Insert of existing embedding ID: auto003
# Add of existing embedding ID: auto003
# Insert of existing embedding ID: auto004
# Add of existing embedding ID: auto004
# Insert of existing embedding ID: auto005
# Add of existing embedding ID: auto005
# Insert of existing embedding ID: auto006
# Add of existing embedding ID: auto006
# Insert of existing embedding ID: auto007
# Add of existing embedding ID: auto007
# Insert of existing embedding ID: auto008
# Add of existing embedding ID: auto008
# Insert of existing embedding ID: auto009
# Add of existing embedding ID: auto009
# Insert of existing embedding ID: auto010
# Add of existing embedding ID: auto010
# Insert of existing embedding ID: auto001
# Add of existing embedding ID: auto001
# Insert of existing embedding ID: auto002
# Add of existing embedding ID: auto002
# Insert of existing embedding ID: auto003
# Add of existing embedding ID: auto003
# Insert of existing embedding ID: auto004
# Add of existing embedding ID: auto004
# Insert of existing embedding ID: auto005
# Add of existing embedding ID: auto005
# Insert of existing embedding ID: auto006
# Add of existing embedding ID: auto006
# Insert of existing embedding ID: auto007
# Add of existing embedding ID: auto007
# Insert of existing embedding ID: auto008
# Add of existing embedding ID: auto008
# Insert of existing embedding ID: auto009
# Add of existing embedding ID: auto009
# Insert of existing embedding ID: auto010
# Add of existing embedding ID: auto010
# Insert of existing embedding ID: auto011
# Add of existing embedding ID: auto011
# Insert of existing embedding ID: auto012
# Add of existing embedding ID: auto012
# Insert of existing embedding ID: auto013
# Add of existing embedding ID: auto013
# Insert of existing embedding ID: auto014
# Add of existing embedding ID: auto014
# Insert of existing embedding ID: auto015
# Add of existing embedding ID: auto015
# Insert of existing embedding ID: auto016
# Add of existing embedding ID: auto016
# Insert of existing embedding ID: auto017
# Add of existing embedding ID: auto017
# Insert of existing embedding ID: auto018
# Add of existing embedding ID: auto018
# Insert of existing embedding ID: auto019
# Add of existing embedding ID: auto019
# Insert of existing embedding ID: auto020
# Add of existing embedding ID: auto020
# Insert of existing embedding ID: auto021
# Add of existing embedding ID: auto021
# Insert of existing embedding ID: auto022
# Add of existing embedding ID: auto022
# Insert of existing embedding ID: auto023
# Add of existing embedding ID: auto023
# Insert of existing embedding ID: auto024
# Add of existing embedding ID: auto024
# Insert of existing embedding ID: auto025
# Add of existing embedding ID: auto025
# ✅ DONE — Chroma rebuilt with SAFE 768-dim embeddings
# 📁 New store: ./chroma_store_768
# 📊 Total items: 51

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
import json
import numpy as np
import chromadb

load_dotenv()

# Backend config (.env)
MODEL_BACKEND = os.getenv("MODEL_BACKEND", "ollama")
MODEL_NAME = os.getenv("MODEL_NAME", "llama3.2")
OLLAMA_API_BASE = os.getenv("OLLAMA_API_BASE", "http://localhost:11434")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "ollama")

# Configure OpenAI to talk to Ollama
os.environ["OPENAI_API_BASE"] = f"{OLLAMA_API_BASE}/v1"
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

client_ai = OpenAI()

print(f"🔗 LLM Backend: {MODEL_BACKEND} | Model: {MODEL_NAME}")
# Out:
# 🔗 LLM Backend: ollama | Model: llama3.2

# %%
import json
import re
import time
from openai import OpenAI

client = OpenAI()

# ------------------------------------------------------
#  Helper: find JSON region
# ------------------------------------------------------
def detect_json(text):
    start = text.find("{")
    end = text.rfind("}")
    if start == -1 or end == -1:
        return None
    return text[start:end+1]

# ------------------------------------------------------
#  Helper: repair malformed JSON
# ------------------------------------------------------
def clean_json_block(text):
    # remove code fences
    text = text.replace("```json", "").replace("```", "")

    # remove trailing commas
    text = re.sub(r",\s*}", "}", text)
    text = re.sub(r",\s*]", "]", text)

    # fix smart quotes
    text = text.replace("“", '"').replace("”", '"')

    # try parse normally
    try:
        return json.loads(text)
    except:
        # last_fix
        text = text.replace("'", '"')
        text = text.replace(",}", "}")
        text = text.replace(",]", "]")
        return json.loads(text)

# ------------------------------------------------------
#  llama3.2 request with multiple retries
# ------------------------------------------------------
def call_llama_json(prompt, retries=5):
    for attempt in range(retries):
        out = client.chat.completions.create(
            model="llama3.2",
            messages=[{"role": "user", "content": prompt}]
        )

        raw = out.choices[0].message.content

        # extract JSON
        json_blob = detect_json(raw)

        if json_blob:
            try:
                return clean_json_block(json_blob)
            except:
                pass  # continue retry

        time.sleep(1.2)

    # FINAL fallback if llama fails
    return {
        "titles": ["fallback title 1", "fallback title 2"],
        "descriptions": ["fallback description 1"]
    }

# ------------------------------------------------------
#  Normalize missing keys (avoid KeyError)
# ------------------------------------------------------
def normalize_result(a):
    if "titles" not in a or not isinstance(a["titles"], list):
        a["titles"] = ["fallback title 1"]

    if "descriptions" not in a or not isinstance(a["descriptions"], list):
        a["descriptions"] = ["fallback description 1"]

    # ensure all values are strings
    a["titles"] = [str(x) for x in a["titles"]]
    a["descriptions"] = [str(x) for x in a["descriptions"]]

    return a

# ------------------------------------------------------
#  Augment function
# ------------------------------------------------------
def augment_text(title, desc):
    prompt = f"""
Generate:
- 10 paraphrased titles
- 5 paraphrased descriptions

Return ONLY JSON:
{{
  "titles": ["t1","t2",...],
  "descriptions": ["d1","d2",...]
}}

Title: {title}
Description: {desc}
"""
    result = call_llama_json(prompt)
    return normalize_result(result)

# ------------------------------------------------------
#  MAIN PIPELINE (RUNS WITHOUT CRASHING)
# ------------------------------------------------------
orig = json.load(open("embeddings/projects-embedded.json"))
augmented = []

for item in orig:
    a = augment_text(item["title"], item["description"])

    # titles
    for t in a["titles"]:
        augmented.append({
            "project_id": item["project_id"] + "_t",
            "title": t,
            "description": item["description"],
            "domain": item["domain"]
        })

    # descriptions
    for d in a["descriptions"]:
        augmented.append({
            "project_id": item["project_id"] + "_d",
            "title": item["title"],
            "description": d,
            "domain": item["domain"]
        })

with open("augmented.json", "w", encoding="utf-8") as f:
    json.dump(augmented, f, indent=2, ensure_ascii=False)

print("✔ Augmentation completed successfully.")
# Out:
# ✔ Augmentation completed successfully.

# %%
import chromadb
import numpy as np
from sentence_transformers import SentenceTransformer
from openai import OpenAI
from dotenv import load_dotenv
import os
import json
import numpy as np
import chromadb

embedder = SentenceTransformer("all-MiniLM-L6-v2")  # 768-dim

client = chromadb.PersistentClient("./chroma_aug_store")
coll = client.create_collection("DBMS-25-AUG")

# FIX IS HERE 👇
with open("augmented.json", "r", encoding="utf-8") as f:
    aug = json.load(f)

for item in aug:
    emb = embedder.encode(item["title"]) 
    coll.add(
        ids=[item["project_id"]],
        embeddings=[emb.tolist()],
        metadatas=[item],
        documents=[item["title"]]
    )

print("AUG collection ready!")
# Out:
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\transformers\utils\generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\transformers\utils\generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\sushm\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_d
# Insert of existing embedding ID: auto003_d
# Add of existing embedding ID: auto003_d
# Insert of existing embedding ID: auto003_d
# Add of existing embedding ID: auto003_d
# Insert of existing embedding ID: auto003_d
# Add of existing embedding ID: auto003_d
# Insert of existing embedding ID: auto003_d
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_d
# Insert of existing embedding ID: auto005_d
# Add of existing embedding ID: auto005_d
# Insert of existing embedding ID: auto005_d
# Add of existing embedding ID: auto005_d
# Insert of existing embedding ID: auto005_d
# Add of existing embedding ID: auto005_d
# Insert of existing embedding ID: auto005_d
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_d
# Insert of existing embedding ID: auto006_d
# Add of existing embedding ID: auto006_d
# Insert of existing embedding ID: auto006_d
# Add of existing embedding ID: auto006_d
# Insert of existing embedding ID: auto006_d
# Add of existing embedding ID: auto006_d
# Insert of existing embedding ID: auto006_d
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_d
# Insert of existing embedding ID: auto007_d
# Add of existing embedding ID: auto007_d
# Insert of existing embedding ID: auto007_d
# Add of existing embedding ID: auto007_d
# Insert of existing embedding ID: auto007_d
# Add of existing embedding ID: auto007_d
# Insert of existing embedding ID: auto007_d
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_d
# Insert of existing embedding ID: auto014_d
# Add of existing embedding ID: auto014_d
# Insert of existing embedding ID: auto014_d
# Add of existing embedding ID: auto014_d
# Insert of existing embedding ID: auto014_d
# Add of existing embedding ID: auto014_d
# Insert of existing embedding ID: auto014_d
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_t
# Insert of existing embedding ID: auto001_t
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto001_d
# Insert of existing embedding ID: auto001_d
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_t
# Insert of existing embedding ID: auto002_t
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto002_d
# Insert of existing embedding ID: auto002_d
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_t
# Insert of existing embedding ID: auto003_t
# Add of existing embedding ID: auto003_d
# Insert of existing embedding ID: auto003_d
# Add of existing embedding ID: auto003_d
# Insert of existing embedding ID: auto003_d
# Add of existing embedding ID: auto003_d
# Insert of existing embedding ID: auto003_d
# Add of existing embedding ID: auto003_d
# Insert of existing embedding ID: auto003_d
# Add of existing embedding ID: auto003_d
# Insert of existing embedding ID: auto003_d
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_t
# Insert of existing embedding ID: auto004_t
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto004_d
# Insert of existing embedding ID: auto004_d
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_t
# Insert of existing embedding ID: auto005_t
# Add of existing embedding ID: auto005_d
# Insert of existing embedding ID: auto005_d
# Add of existing embedding ID: auto005_d
# Insert of existing embedding ID: auto005_d
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_t
# Insert of existing embedding ID: auto006_t
# Add of existing embedding ID: auto006_d
# Insert of existing embedding ID: auto006_d
# Add of existing embedding ID: auto006_d
# Insert of existing embedding ID: auto006_d
# Add of existing embedding ID: auto006_d
# Insert of existing embedding ID: auto006_d
# Add of existing embedding ID: auto006_d
# Insert of existing embedding ID: auto006_d
# Add of existing embedding ID: auto006_d
# Insert of existing embedding ID: auto006_d
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_t
# Insert of existing embedding ID: auto007_t
# Add of existing embedding ID: auto007_d
# Insert of existing embedding ID: auto007_d
# Add of existing embedding ID: auto007_d
# Insert of existing embedding ID: auto007_d
# Add of existing embedding ID: auto007_d
# Insert of existing embedding ID: auto007_d
# Add of existing embedding ID: auto007_d
# Insert of existing embedding ID: auto007_d
# Add of existing embedding ID: auto007_d
# Insert of existing embedding ID: auto007_d
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_t
# Insert of existing embedding ID: auto008_t
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto008_d
# Insert of existing embedding ID: auto008_d
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_t
# Insert of existing embedding ID: auto009_t
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto009_d
# Insert of existing embedding ID: auto009_d
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_t
# Insert of existing embedding ID: auto010_t
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto010_d
# Insert of existing embedding ID: auto010_d
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_t
# Insert of existing embedding ID: auto011_t
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto011_d
# Insert of existing embedding ID: auto011_d
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_t
# Insert of existing embedding ID: auto012_t
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto012_d
# Insert of existing embedding ID: auto012_d
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_t
# Insert of existing embedding ID: auto013_t
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto013_d
# Insert of existing embedding ID: auto013_d
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_t
# Insert of existing embedding ID: auto014_t
# Add of existing embedding ID: auto014_d
# Insert of existing embedding ID: auto014_d
# Add of existing embedding ID: auto014_d
# Insert of existing embedding ID: auto014_d
# Add of existing embedding ID: auto014_d
# Insert of existing embedding ID: auto014_d
# Add of existing embedding ID: auto014_d
# Insert of existing embedding ID: auto014_d
# Add of existing embedding ID: auto014_d
# Insert of existing embedding ID: auto014_d
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_d
# Insert of existing embedding ID: auto022_d
# Add of existing embedding ID: auto022_d
# Insert of existing embedding ID: auto022_d
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto026_t
# Insert of existing embedding ID: auto026_t
# Add of existing embedding ID: auto026_t
# Insert of existing embedding ID: auto026_t
# Add of existing embedding ID: auto026_t
# Insert of existing embedding ID: auto026_t
# Add of existing embedding ID: auto026_t
# Insert of existing embedding ID: auto026_t
# Add of existing embedding ID: auto026_d
# Insert of existing embedding ID: auto026_d
# Add of existing embedding ID: auto026_d
# Insert of existing embedding ID: auto026_d
# Add of existing embedding ID: auto026_d
# Insert of existing embedding ID: auto026_d
# Add of existing embedding ID: auto026_d
# Insert of existing embedding ID: auto026_d
# ...
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_t
# Insert of existing embedding ID: auto015_t
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto015_d
# Insert of existing embedding ID: auto015_d
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_t
# Insert of existing embedding ID: auto016_t
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto016_d
# Insert of existing embedding ID: auto016_d
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_t
# Insert of existing embedding ID: auto017_t
# Add of existing embedding ID: auto017_d
# Insert of existing embedding ID: auto017_d
# Add of existing embedding ID: auto017_d
# Insert of existing embedding ID: auto017_d
# Add of existing embedding ID: auto017_d
# Insert of existing embedding ID: auto017_d
# Add of existing embedding ID: auto017_d
# Insert of existing embedding ID: auto017_d
# Add of existing embedding ID: auto017_d
# Insert of existing embedding ID: auto017_d
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_t
# Insert of existing embedding ID: auto018_t
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto018_d
# Insert of existing embedding ID: auto018_d
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_t
# Insert of existing embedding ID: auto019_t
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto019_d
# Insert of existing embedding ID: auto019_d
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_t
# Insert of existing embedding ID: auto020_t
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto020_d
# Insert of existing embedding ID: auto020_d
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_t
# Insert of existing embedding ID: auto021_t
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto021_d
# Insert of existing embedding ID: auto021_d
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_t
# Insert of existing embedding ID: auto022_t
# Add of existing embedding ID: auto022_d
# Insert of existing embedding ID: auto022_d
# Add of existing embedding ID: auto022_d
# Insert of existing embedding ID: auto022_d
# Add of existing embedding ID: auto022_d
# Insert of existing embedding ID: auto022_d
# Add of existing embedding ID: auto022_d
# Insert of existing embedding ID: auto022_d
# Add of existing embedding ID: auto022_d
# Insert of existing embedding ID: auto022_d
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_t
# Insert of existing embedding ID: auto023_t
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto023_d
# Insert of existing embedding ID: auto023_d
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_t
# Insert of existing embedding ID: auto024_t
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto024_d
# Insert of existing embedding ID: auto024_d
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_t
# Insert of existing embedding ID: auto025_t
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# Add of existing embedding ID: auto025_d
# Insert of existing embedding ID: auto025_d
# AUG collection ready!

# %%
# ===============================
# 🔍 FULL CHROMADB VALIDATION NOTEBOOK
# ===============================

import os
import json
import numpy as np
import chromadb

CHROMA_PATH = "./chroma_store_aug"
COLLECTION = "DBMS-25-AUG"

client = chromadb.PersistentClient(path=CHROMA_PATH)
coll = client.get_collection(COLLECTION)

print("====================================")
print("🔍 Checking ChromaDB Status...")
print("====================================")

# -------------------------
# 1. Basic Info
# -------------------------
print(f"✔ Collection: {coll.name}")
print(f"📦 Total Items: {coll.count()}")


# -------------------------
# 2. Fetch sample
# -------------------------
sample = coll.get(limit=1, include=["embeddings", "documents", "metadatas"])

print("\n=== SAMPLE RECORD (JSON-SAFE) ===")
safe_sample = json.loads(json.dumps(sample, default=lambda x: x.tolist() if isinstance(x, np.ndarray) else str(x), indent=2))
print(json.dumps(safe_sample, indent=2))


# -------------------------
# 3. Detect Embedding Dim (correct for ndarray, list, nested list)
# -------------------------
embs = sample.get("embeddings", None)
dim = None

if isinstance(embs, list) and len(embs) > 0:
    first = embs[0]

    if isinstance(first, np.ndarray):
        dim = first.shape[0]

    elif isinstance(first, list) and len(first) > 0 and isinstance(first[0], (float, int)):
        dim = len(first)

    elif isinstance(first, list) and len(first) > 0 and isinstance(first[0], list):
        dim = len(first[0])

print(f"\n📐 Embedding Dimension: {dim}")


# ===============================
# 4. FULL VALIDATION
# ===============================

print("\n====================================")
print("🔎 FULL VALIDATION OF ALL EMBEDDINGS")
print("====================================")

records = coll.get(include=["embeddings"], limit=20000)

all_embs = records["embeddings"]
ids = records["ids"]

bad_count = 0
dims = set()

for idx, emb in enumerate(all_embs):
    id_ = ids[idx]

    # ndarray
    if isinstance(emb, np.ndarray):
        dims.add(emb.shape[0])

    # list of floats
    elif isinstance(emb, list) and len(emb) > 0 and isinstance(emb[0], (float, int)):
        dims.add(len(emb))

    # nested list
    elif isinstance(emb, list) and len(emb) > 0 and isinstance(emb[0], list):
        dims.add(len(emb[0]))

    else:
        print(f"❌ Bad embedding for ID: {id_}")
        bad_count += 1


print("\n=== VALIDATION REPORT ===")
print(f"✔ Total embeddings checked: {len(all_embs)}")
print(f"📐 Unique embedding dimensions found: {dims}")
print(f"❌ Corrupted embeddings: {bad_count}")

if len(dims) == 1:
    print("🎉 Good news: All embeddings have a consistent dimension.")
else:
    print("⚠️ WARNING: Mixed embedding dimensions detected!")

print("\n🔍 DB Check Complete.")
# Out:
# 🔍 Checking ChromaDB status...
#
# ✔ Collection found: DBMS-25-AUG
# 📦 Total items: 102
#
# === SAMPLE RECORD (JSON-SAFE) ===
# {
#   "ids": [
#     "auto001_t"
#   ],
#   "embeddings": [
#     [
#       -0.0740911141037941,
#       0.10007232427597046,
#       -0.06078357994556427,
#       0.042467281222343445,
#       -0.03277324140071869,
#       -0.010189599357545376,
#       0.06510160863399506,
#       -0.05643374100327492,
#       -0.03331286087632179,
#       -0.037888526916503906,
#       -0.018932858482003212,
#       -0.004982047248631716,
#       0.053329259157180786,
#       0.0047050220891833305,
#       -0.04416971281170845,
#       0.0747058168053627,
#       -0.01451728492975235,
#       0.04346424341201782,
#       -0.005094795022159815,
#       -0.04766011983156204,
#       -0.05374922975897789,
#       -0.0029457523487508297,
#       -0.0938207134604454,
#       0.008722788654267788,
#       0.017974702641367912,
#       0.00849444605410099,
#       0.04606930539011955,
#       -0.03254694119095802,
#       -0.04125959798693657,
#       -0.04016202315688133,
#       0.004895590245723724,
#       -0.07857280969619751,
#       0.02342182584106922,
#       0.08366361260414124,
#       -0.0690990686416626,
#       0.04236730933189392,
#       0.043155960738658905,
#       -0.032553549855947495,
#       -0.014185748994350433,
#       -0.04139029607176781,
#       -0.02718910202383995,
#       -0.03534203767776489,
#       -0.04430309310555458,
#       0.05986849218606949,
#       -0.0302260871976614,
#       0.026335714384913445,
#       0.065370112657547,
#       0.027529176324605942,
#       -0.052259236574172974,
#       -0.03154044970870018,
#       -0.06558940559625626,
#       0.016490299254655838,
#       0.013564526103436947,
#       0.04473887011408806,
#       -0.036480993032455444,
#       -0.06038718670606613,
#       -0.023686349391937256,
#       -0.030717214569449425,
#       0.0032395776361227036,
#       -0.02403852716088295,
#       -0.03735046088695526,
#       0.016400909051299095,
#       0.004034548997879028,
#       -0.011782930232584476,
#       -0.038357898592948914,
#       0.0750449150800705,
#       0.0473223440349102,
#       0.03780672326683998,
#       -0.0024047542829066515,
#       0.044832419604063034,
#       0.030432581901550293,
#       0.012963809072971344,
#       -0.013399961404502392,
#       -0.0394367091357708,
#       0.00515753822401166,
#       0.01015979703515768,
#       -0.11701911687850952,
#       -0.059244029223918915,
#       0.0707240179181099,
#       -0.07934736460447311,
#       0.04767213389277458,
#       -0.10814821720123291,
#       0.012185860425233841,
#       0.0948915034532547,
#       0.08013901859521866,
#       0.007651977241039276,
#       0.0025267726741731167,
#       0.001197142875753343,
#       0.028116794303059578,
#       -0.024544116109609604,
#       0.015527516603469849,
#       0.10491584241390228,
#       0.005549756344407797,
#       -0.009699606336653233,
#       -0.01341993361711502,
#       -0.043752409517765045,
#       -0.051072537899017334,
#       -0.027079738676548004,
#       0.020520923659205437,
#       0.07624214887619019,
#       -0.09006500989198685,
#       0.06754951179027557,
#       0.005556587595492601,
#       0.013286287896335125,
#       -0.01912984997034073,
#       0.034469373524188995,
#       0.05101929232478142,
#       0.037896059453487396,
#       -0.02619107998907566,
#       0.04744109883904457,
#       0.012013199739158154,
#       0.020394781604409218,
#       0.054745227098464966,
#       0.0009537119185552001,
#       0.040979936718940735,
#       -0.029062233865261078,
#       -0.05941169336438179,
#       0.11299927532672882,
#       -0.05607133358716965,
#       0.08988918364048004,
#       0.03844309225678444,
#       0.1095132827758789,
#       0.049464598298072815,
#       0.04969949275255203,
#       0.00740057323127985,
#       -0.049354277551174164,
#       -0.09908582270145416,
#       -1.3536836823725994e-33,
#       0.00559250870719552,
#       0.007910291664302349,
#       0.0065701911225914955,
#       0.01703585684299469,
#       -0.04572810232639313,
#       0.03115936554968357,
#       -0.05395255982875824,
#       -0.01007880736142397,
#       -0.0833117663860321,
#       0.026917705312371254,
#       0.0060108317993581295,
#       0.06765522807836533,
#       0.012000825256109238,
#       0.0022147363051772118,
#       0.0606328509747982,
#       0.06113516911864281,
#       0.04508519545197487,
#       0.0725812166929245,
#       0.06700156629085541,
#       -0.04293779283761978,
#       0.09050633758306503,
#       -0.03777352720499039,
#       0.020469028502702713,
#       0.04044753313064575,
#       0.049831047654151917,
#       -0.0024587211664766073,
#       0.07134642452001572,
#       -0.010508794337511063,
#       0.08416590094566345,
#       0.03196685388684273,
#       -0.03081493265926838,
#       0.05433887615799904,
#       0.09156744927167892,
#       0.03388381004333496,
#       0.08505456894636154,
#       -0.019602587446570396,
#       0.06720571964979172,
#       -0.04438173770904541,
#       0.024503247812390327,
#       0.008656984195113182,
#       0.050212208181619644,
#       0.025501394644379616,
#       0.04725297540426254,
#       -0.026655416935682297,
#       -0.07408539205789566,
#       0.06428630650043488,
#       0.022989559918642044,
#       0.04725581035017967,
#       0.06847533583641052,
#       -0.020946132019162178,
#       -0.02597971260547638,
#       -0.025635546073317528,
#       -0.07524091005325317,
#       0.010043419897556305,
#       -0.015440919436514378,
#       -0.032711345702409744,
#       -0.05393451452255249,
#       0.024603579193353653,
#       0.07494809478521347,
#       0.06094183772802353,
#       -0.13314023613929749,
#       0.0007170533062890172,
#       -0.047234803438186646,
#       -0.08519724756479263,
#       -0.08077625185251236,
#       -0.03274976834654808,
#       -0.06920544058084488,
#       -0.03622353449463844,
#       0.03866202384233475,
#       0.06538152694702148,
#       0.009987466037273407,
#       -0.02757730521261692,
#       0.05426392704248428,
#       0.06906050443649292,
#       -0.022180533036589622,
#       -0.03557861968874931,
#       0.013643196783959866,
#       -0.047812122851610184,
#       0.026779236271977425,
#       -0.0035186330787837505,
#       0.009665085934102535,
#       -0.08023766428232193,
#       0.023902440443634987,
#       -0.03398924320936203,
#       -0.05316054821014404,
#       -0.05048232898116112,
#       -0.0028268606401979923,
#       -0.01462489366531372,
#       -0.052154771983623505,
#       0.022727031260728836,
#       -0.06200455129146576,
#       -0.007545498199760914,
#       0.08364379405975342,
#       -0.07141759246587753,
#       -0.005764988251030445,
#       4.471080466251401e-34,
#       -0.10093823820352554,
#       -0.010350680910050869,
#       0.018483368679881096,
#       0.12002268433570862,
#       0.044301461428403854,
#       0.018986515700817108,
#       0.05123338848352432,
#       -0.05433826893568039,
#       0.10153817385435104,
#       -0.035820119082927704,
#       0.005917389877140522,
#       -0.0484185516834259,
#       0.0706319510936737,
#       -0.026016274467110634,
#       0.07107919454574585,
#       0.07061552256345749,
#       -0.029332229867577553,
#       -0.020496545359492302,
#       -0.013829055242240429,
#       0.028293929994106293,
#       -0.052499864250421524,
#       0.02951694279909134,
#       -0.0776449516415596,
#       0.022614363580942154,
#       0.10056298971176147,
#       0.07442110776901245,
#       -0.01759832724928856,
#       0.06366706639528275,
#       0.10720512270927429,
#       0.07487035542726517,
#       -0.05771259590983391,
#       -0.02461377903819084,
#       -0.03696488216519356,
#       -0.060542650520801544,
#       -0.09676653146743774,
#       -0.0157963577657938,
#       0.09644682705402374,
#       0.10336766391992569,
#       -0.0005464275018312037,
#       -0.03486916795372963,
#       -0.002108478220179677,
#       -0.035002417862415314,
#       -0.019663099199533463,
#       -0.009973311796784401,
#       0.07624538987874985,
#       0.04670386761426926,
#       0.056639865040779114,
#       0.1505269706249237,
#       -0.04141279309988022,
#       -0.10514462739229202,
#       -0.02624218352138996,
#       0.0521569550037384,
#       0.006514707114547491,
#       -0.04482666030526161,
#       0.03878682851791382,
#       -0.07197421789169312,
#       0.01395870465785265,
#       -0.028228675946593285,
#       -0.11851087957620621,
#       0.03883693739771843,
#       0.03196575120091438,
#       -0.006611150689423084,
#       0.008844023570418358,
#       0.07551756501197815,
#       -0.017346778884530067,
#       -0.0483030267059803,
#       -0.006872259080410004,
#       -0.07649850100278854,
#       0.006018210668116808,
#       0.0046617272309958935,
#       0.01657452993094921,
#       -0.0811440721154213,
#       -0.009191729128360748,
#       -0.03111976385116577,
#       0.0003384892188478261,
#       -0.0054561672732234,
#       -0.04427928104996681,
#       0.043110426515340805,
#       0.014548067934811115,
#       0.13161274790763855,
#       0.05540117621421814,
#       -0.010126267559826374,
#       0.033854950219392776,
#       -0.027119364589452744,
#       0.059448838233947754,
#       -0.07232212275266647,
#       0.07956327497959137,
#       -0.07750138640403748,
#       0.005849951412528753,
#       0.006062389351427555,
#       -0.13041254878044128,
#       0.014254435896873474,
#       -0.052520520985126495,
#       0.04945066198706627,
#       0.10385376214981079,
#       -1.3179215052616655e-08,
#       0.052590616047382355,
#       -0.05379580706357956,
#       0.03410593420267105,
#       -0.002573596313595772,
#       0.07301276922225952,
#       -0.02170005813241005,
#       -0.027529317885637283,
#       -0.017254693433642387,
#       -0.014917285181581974,
#       -0.0361979603767395,
#       0.025552209466695786,
#       -0.05434544011950493,
#       -0.03056657500565052,
#       -0.037708695977926254,
#       0.0063330973498523235,
#       -0.009546223096549511,
#       0.040860921144485474,
#       -0.06937367469072342,
#       -0.012429909780621529,
#       -0.05392291769385338,
#       -0.067012719810009,
#       -0.01836448162794113,
#       -0.04026821628212929,
#       0.006345637142658234,
#       -0.03462982922792435,
#       0.019540149718523026,
#       -0.006393597926944494,
#       0.00730097945779562,
#       -0.0487101674079895,
#       0.07154637575149536,
#       -0.049604568630456924,
#       -0.09968847781419754,
#       0.028028300032019615,
#       -0.00547800911590457,
#       0.012939679436385632,
#       0.005560932215303183,
#       -0.0531618632376194,
#       0.053292129188776016,
#       0.050770245492458344,
#       -0.0685223713517189,
#       0.05507774278521538,
#       -0.005521511193364859,
#       -0.043116386979818344,
#       0.026039447635412216,
#       -0.007478482089936733,
#       -0.07675905525684357,
#       0.07039876282215118,
#       -0.03976329788565636,
#       -0.010775328613817692,
#       0.011792263016104698,
#       0.03777557611465454,
#       -0.04498160257935524,
#       0.03237909451127052,
#       0.04814773052930832,
#       0.04832782223820686,
#       0.05890575796365738,
#       -0.025328299030661583,
#       -0.025959637016057968,
#       -0.027856985107064247,
#       0.022398779168725014,
#       -0.014997824095189571,
#       -0.08007548749446869,
#       -0.028389785438776016,
#       -0.10198604315519333
#     ]
#   ],
#   "documents": [
#     "Analyzing Instagram Reach through Machine Learning"
#   ],
#   "uris": null,
#   "data": null,
#   "metadatas": [
#     {
#       "description": "Instagram reach analysis is a vital topic for social media marketing. This project aims at teaching learners how to use data to analyze their Instagram reach. It involves collecting data on the reach of your past posts and using Python to understand how different factors affect the number of people who see your posts.\n\nLearning outcomes: \n\n    Understanding of Machine Learning concepts: Have a solid grasp of the fundamentals of machine learning, its workflow, and common data preprocessing techniques \n    Data Exploration:  Use of Python libraries like Pandas and NumPy for data manipulation and analysis\n    Data Visualization: Knowledge of Python in-built tools like Matplotlib, Seaborn, and Plotly for creating charts and tables and improved data analysis \n\nHow to build this machine learning project:\n\n    Manually gather \u2018reach\u2019 data from Instagram insights about past posts\n    Import them from CSV file into Python using libraries like Pandas, and clean and organize the data for analysis \n    Use Python libraries like Matplotlib, Seaborn, and Plotly to calculate different metrics, create data visualization, and identify patterns \n    Depending on your data analysis, draw conclusions on which factors influence your Instagram reach \n\nReal world applications: \n\n    Marketers can use this tool to identify what attracts consumers\n    Businesses can use them to see how people welcome their products\n    Content creators use it to understand which kind of post goes viral and attract followers \n\n\ud83d\udc49 Find the source code",
#       "domain": "Artificial Intelligence / Data Science",
#       "project_id": "auto001_t",
#       "title": "Analyzing Instagram Reach through Machine Learning"
#     }
#   ],
#   "included": [
#     "embeddings",
#     "documents",
#     "metadatas"
#   ]
# }
# 📐 Embedding Dimension: None
